# %% [markdown]
# ## Tokenization&stopwords removal

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
STOP = set(nltk.corpus.stopwords.words("english"))

class Sentence:
    def __init__(self, sentence):
        self.raw = sentence
        normalized_sentence = sentence.replace("‘", "'").replace("’", "'").replace(",","").replace(".","").replace("'","")
        self.tokens = [t.lower() for t in nltk.word_tokenize(normalized_sentence)]
        self.tokens_without_stop = [t for t in self.tokens if t not in STOP]
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11004]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading punkt: <urlopen error [Errno 11004]
# [nltk_data]     getaddrinfo failed>

# %% [markdown]
# - Example for Class Sentence

# %%
st = Sentence("Wetpaint is a technology platform company that uses its proprietary state-of-the-art technology and expertise in social media to build and monetize audiences for digital publishers. Wetpaint’s own online property, Wetpaint Entertainment, an entertainment news site that attracts more than 12 million unique visitors monthly and has over 2 million Facebook fans, is a proof point to the company’s success in building and engaging audiences. Media companies can license Wetpaint’s platform which includes a dynamic playbook tailored to their individual needs and comprehensive training. Founded by Internet pioneer Ben Elowitz, and with offices in New York and Seattle, Wetpaint is backed by Accel Partners, the investors behind Facebook.")

# %%
st.tokens_without_stop
# Out:
# ['wetpaint',
#  'technology',
#  'platform',
#  'company',
#  'uses',
#  'proprietary',
#  'state-of-the-art',
#  'technology',
#  'expertise',
#  'social',
#  'media',
#  'build',
#  'monetize',
#  'audiences',
#  'digital',
#  'publishers',
#  'wetpaints',
#  'online',
#  'property',
#  'wetpaint',
#  'entertainment',
#  'entertainment',
#  'news',
#  'site',
#  'attracts',
#  '12',
#  'million',
#  'unique',
#  'visitors',
#  'monthly',
#  '2',
#  'million',
#  'facebook',
#  'fans',
#  'proof',
#  'point',
#  'companys',
#  'success',
#  'building',
#  'engaging',
#  'audiences',
#  'media',
#  'companies',
#  'license',
#  'wetpaints',
#  'platform',
#  'includes',
#  'dynamic',
#  'playbook',
#  'tailored',
#  'individual',
#  'needs',
#  'comprehensive',
#  'training',
#  'founded',
#  'internet',
#  'pioneer',
#  'ben',
#  'elowitz',
#  'offices',
#  'new',
#  'york',
#  'seattle',
#  'wetpaint',
#  'backed',
#  'accel',
#  'partners',
#  'investors',
#  'behind',
#  'facebook']

# %% [markdown]
# ## Word2vec - WordEmbedding

# %%
import gensim
from gensim.models import Word2Vec
import os
PATH_TO_WORD2VEC = os.path.expanduser("data/GoogleNews-vectors-negative300.bin")
word2vec = gensim.models.KeyedVectors.load_word2vec_format(PATH_TO_WORD2VEC, binary=True)

# %% [markdown]
# ## Glove - WordEmbedding

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
PATH_TO_GLOVE = os.path.expanduser("data/glove.42B.300d.txt")
tmp_file = "data/glove.42B.300d.w2v.txt"
glove2word2vec(PATH_TO_GLOVE, tmp_file)
glove = gensim.models.KeyedVectors.load_word2vec_format(tmp_file)

# %% [markdown]
# - add weight to word embeddings

# %%
import csv

PATH_TO_FREQUENCIES_FILE = "data/frequencies.tsv"
PATH_TO_DOC_FREQUENCIES_FILE = "data/doc_frequencies.tsv"

def read_tsv(f):
    frequencies = {}
    with open(f) as tsv:
        tsv_reader = csv.reader(tsv, delimiter="\t")
        for row in tsv_reader: 
            frequencies[row[0]] = int(row[1])
        
    return frequencies
        
frequencies = read_tsv(PATH_TO_FREQUENCIES_FILE)
doc_frequencies = read_tsv(PATH_TO_DOC_FREQUENCIES_FILE)
doc_frequencies["NUM_DOCS"] = 1288431

# %% [markdown]
# ## Similarity computation

# %%
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import math
import numpy as np

def run_avg_benchmark(sentences1, sentences2, model=None, use_stoplist=False, doc_freqs=None): 

    if doc_freqs is not None:
        N = doc_freqs["NUM_DOCS"]
    
    tokens1 = sentences1.tokens_without_stop if use_stoplist else sentences1.tokens
    tokens2 = sentences2.tokens_without_stop if use_stoplist else sentences2.tokens

    tokens1 = [token for token in tokens1 if token in model]
    tokens2 = [token for token in tokens2 if token in model]

#     if len(tokens1) == 0 or len(tokens2) == 0:
#         sims.append(0)
#         continue

    tokfreqs1 = Counter(tokens1)
    tokfreqs2 = Counter(tokens2)

    weights1 = [tokfreqs1[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                for token in tokfreqs1] if doc_freqs else None
    weights2 = [tokfreqs2[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                for token in tokfreqs2] if doc_freqs else None

    embedding1 = np.average([model[token] for token in tokfreqs1], axis=0, weights=weights1).reshape(1, -1)
    embedding2 = np.average([model[token] for token in tokfreqs2], axis=0, weights=weights2).reshape(1, -1)
    sim = cosine_similarity(embedding1, embedding2)[0][0]

    return sim

def run_wmd_benchmark(sent1, sent2, model, use_stoplist=False):

    tokens1 = sent1.tokens_without_stop if use_stoplist else sent1.tokens
    tokens2 = sent2.tokens_without_stop if use_stoplist else sent2.tokens

    tokens1 = [token for token in tokens1 if token in model]
    tokens2 = [token for token in tokens2 if token in model]

    if len(tokens1) == 0 or len(tokens2) == 0:
        tokens1 = [token for token in sent1.tokens if token in model]
        tokens2 = [token for token in sent2.tokens if token in model]

    sim = model.wmdistance(tokens1, tokens2)
        
    return sim

from sklearn.decomposition import TruncatedSVD

def remove_first_principal_component(X):
    svd = TruncatedSVD(n_components=1, n_iter=7, random_state=0)
    svd.fit(X)
    pc = svd.components_
    XX = X - X.dot(pc.transpose()) * pc
    return XX


def run_sif_benchmark(sent1, sent2, model, freqs={}, use_stoplist=False, a=0.001): 
    total_freq = sum(freqs.values())
    embeddings = []
    # SIF requires us to first collect all sentence embeddings and then perform 
    # common component analysis.
    tokens1 = sent1.tokens_without_stop if use_stoplist else sent1.tokens
    tokens2 = sent2.tokens_without_stop if use_stoplist else sent2.tokens

    tokens1 = [token for token in tokens1 if token in model]
    tokens2 = [token for token in tokens2 if token in model]

    weights1 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens1]
    weights2 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens2]

    embedding1 = np.average([model[token] for token in tokens1], axis=0, weights=weights1)
    embedding2 = np.average([model[token] for token in tokens2], axis=0, weights=weights2)

    embeddings.append(embedding1)
    embeddings.append(embedding2)
        
    embeddings = remove_first_principal_component(np.array(embeddings))
    sim = [cosine_similarity(embeddings[idx*2].reshape(1, -1), 
                              embeddings[idx*2+1].reshape(1, -1))[0][0] 
            for idx in range(int(len(embeddings)/2))][0]

    return sim

# %% [markdown]
# ## Loading data

# %%
import pandas as pd
data = pd.read_pickle("baseline.pkl")

# %% [markdown]
# ## Compute similarity

# %%
def return_similarity(data,company_one,company_two,text_type, webm_model,stop_flag,sim_type):
    com_des_one =  data[data["name"] == company_one]["description"].values[0]
#     com_peo_des_one =  data[data["name"] == company_one]["p_description"].values[0]
    com_sh_des_one =  data[data["name"] == company_one]["short_description"].values[0]
    com_des_two =  data[data["name"] == company_two]["description"].values[0]
#     com_peo_des_two =  data[data["name"] == company_two]["p_description"].values[0]
    com_sh_des_two =  data[data["name"] == company_two]["short_description"].values[0]
    com_des_one = com_des_one + str(com_sh_des_one)
#     print(str(com_des_two))
    com_des_two = str(com_des_two) + str(com_sh_des_two)

    if text_type == "only_des":
        if sim_type == "cos":
            similarity = run_avg_benchmark(Sentence(com_des_one),Sentence(com_des_two),model = webm_model, use_stoplist=stop_flag)
        elif sim_type == "wmd":
            similarity = run_wmd_benchmark(Sentence(com_des_one),Sentence(com_des_two),model = webm_model, use_stoplist=stop_flag)
    return similarity

# %%
return_similarity(data,"Airbnb","Brightcove","only_des", glove,False,sim_type = "cos")
# Out:
# 0.9412049

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### 1.1 verify feasibility

# %%
name_ls_finance = data[data.apply(lambda x: "Cloud Computing" in x["category_list"],axis = 1)]["name"]
name_ls_travel = data[data.apply(lambda x: "Travel" in x["category_list"],axis = 1)]["uuid","name"]
name_ls_cloud = data[data.apply(lambda x: "Cloud Computing" in x["category_list"],axis = 1)]["name"]

# %%
data["category_list"] = data["category_list"].fillna("No category")

# %%
finance_companies_ls = list(name_ls_finance)
travel_companies_ls = list(name_ls_travel)
cloud_companies_ls = list(name_ls_cloud)

# %%
for name in finance_companies_ls[:10]:
    sim_ls = []
#     print(name)
    sim = return_similarity(data,"Airbnb",name,"only_des", word2vec,False,sim_type = "cos")
    sim_ls.append(sim)
    print(name,sim)
# Out:
# Zoho 0.76162076
# PBworks 0.8265405
# Box 0.8388816
# Oracle-NetSuite 0.749099
# Big Bang Ventures 0.5666262
# LongJump 0.82523376
# Brightcove 0.7676357
# Limelight Networks 0.7802206
# Nirvanix 0.78128
# INgage Networks 0.7725506

# %%
for name in cloud_companies_ls[:10]:
    sim_ls = []
#     print(name)
    sim = return_similarity(data,"Airbnb",name,"only_des", word2vec,False,sim_type = "cos")
    sim_ls.append(sim)
    print(name,sim)
# Out:
# Zoho 0.76162076
# PBworks 0.8265405
# Box 0.8388816
# Oracle-NetSuite 0.749099
# Big Bang Ventures 0.5666262
# LongJump 0.82523376
# Brightcove 0.7676357
# Limelight Networks 0.7802206
# Nirvanix 0.78128
# INgage Networks 0.7725506

# %%
for name in travel_companies_ls[:10]:
    sim_ls = []
#     print(name)
    sim = return_similarity(data,"Airbnb",name,"only_des", word2vec,False,sim_type = "cos")
    sim_ls.append(sim)
    print(name,sim)
# Out:
# TripUp 0.8351637
# SideStep 0.8549029
# Farecast 0.846826
# Yapta 0.81168526
# TripHub 0.824854
# TVtrip 0.8520464
# Hotelicopter 0.85233414
# Sulake 0.87833744
# TCV 0.7949606
# lastminute.com group 0.8319692

# %%
name_ls_travel = data[data.apply(lambda x: "Travel" in x["category_list"],axis = 1)]

# %%
travel_companies_ls = name_ls_travel[["uuid","name"]]

# %% [markdown]
# ## Database

# %%
import pymongo
client = pymongo.MongoClient(host='localhost', port=27017)
db = client['startups']
collection = db.similarities

# %%
pair = {}
for travel_company in travel_companies_ls[:100]:
    sim = return_similarity(data,"Airbnb",travel_company[1],"only_des", word2vec,False,sim_type = "cos")
    pair["Airbnb"] = {}
    pair["uuid"] = travel_company[0]
    pair["name"] =

# %%
company_ls = data[["uuid","name"]].values

# %%
company_ls = data[data["name"] == "Airbnb"][["uuid","name"]].values

# %%
for company_a in company_ls:
    count = 0
    for travel_company in travel_companies_ls.values:
        print("here is the count {}".format(count))
        pair = {}
        try:
            sim = return_similarity(data,company_a[1],travel_company[1],"only_des", word2vec,False,sim_type = "cos")
        except:
            pass
        pair["id_a"] = company_a[0]
        pair["id_b"] = travel_company[0]
        pair["name_a"] = company_a[1]
        pair["name_b"] = travel_company[1]
        pair["similarity"] = float(sim)
        collection.insert_one(pair)
        count+=1
# Out:
# here is the count 0
# here is the count 1
# here is the count 2
# here is the count 3
# here is the count 4
# here is the count 5
# here is the count 6
# here is the count 7
# here is the count 8
# here is the count 9
# here is the count 10
# here is the count 11
# here is the count 12
# here is the count 13
# here is the count 14
# here is the count 15
# here is the count 16
# here is the count 17
# here is the count 18
# here is the count 19
# here is the count 20
# here is the count 21
# here is the count 22
# here is the count 23
# here is the count 24
# here is the count 25
# here is the count 26
# here is the count 27
# here is the count 28
# here is the count 29
# here is the count 30
# here is the count 31
# here is the count 32
# here is the count 33
# here is the count 34
# here is the count 35
# here is the count 36
# here is the count 37
# here is the count 38
# here is the count 39
# here is the count 40
# here is the count 41
# here is the count 42
# here is the count 43
# here is the count 44
# here is the count 45
# here is the count 46
# here is the count 47
# here is the count 48
# here is the count 49
# here is the count 50
# here is the count 51
# here is the count 52
# here is the count 53
# here is the count 54
# here is the count 55
# here is the count 56
# here is the count 57
# here is the count 58
# here is the count 59
# here is the count 60
# here is the count 61
# here is the count 62
# here is the count 63
# here is the count 64
# here is the count 65
# here is the count 66
# here is the count 67
# here is the count 68
# here is the count 69
# here is the count 70
# here is the count 71
# here is the count 72
# here is the count 73
# here is the count 74
# here is the count 75
# here is the count 76
# here is the count 77
# here is the count 78
# here is the count 79
# here is the count 80
# here is the count 81
# here is the count 82
# here is the count 83
# here is the count 84
# here is the count 85
# here is the count 86
# here is the count 87
# here is the count 88
# here is the count 89
# here is the count 90
# here is the count 91
# here is the count 92
# here is the count 93
# here is the count 94
# here is the count 95
# here is the count 96
# here is the count 97
# here is the count 98
# here is the count 99
# here is the count 100
# here is the count 101
# here is the count 102
# here is the count 103
# here is the count 104
# here is the count 105
# here is the count 106
# here is the count 107
# here is the count 108
# here is the count 109
# here is the count 110
# here is the count 111
# here is the count 112
# here is the count 113
# here is the count 114
# here is the count 115
# here is the count 116
# here is the count 117
# here is the count 118
# here is the count 119
# here is the count 120
# here is the count 121
# here is the count 122
# here is the count 123
# here is the count 124
# here is the count 125
# here is the count 126
# here is the count 127
# here is the count 128
# here is the count 129
# here is the count 130
# here is the count 131
# here is the count 132
# here is the count 133
# here is the count 134
# here is the count 135
# here is the count 136
# here is the count 137
# here is the count 138
# here is the count 139
# here is the count 140
# here is the count 141
# here is the count 142
# here is the count 143
# here is the count 144
# here is the count 145
# here is the count 146
# here is the count 147
# here is the count 148
# here is the count 149
# here is the count 150
# here is the count 151
# here is the count 152
# here is the count 153
# here is the count 154
# here is the count 155
# here is the count 156
# here is the count 157
# here is the count 158
# here is the count 159
# here is the count 160
# here is the count 161
# here is the count 162
# here is the count 163
# here is the count 164
# here is the count 165
# here is the count 166
# here is the count 167
# here is the count 168
# here is the count 169
# here is the count 170
# here is the count 171
# here is the count 172
# here is the count 173
# here is the count 174
# here is the count 175
# here is the count 176
# here is the count 177
# here is the count 178
# here is the count 179
# here is the count 180
# here is the count 181
# here is the count 182
# here is the count 183
# here is the count 184
# here is the count 185
# here is the count 186
# here is the count 187
# here is the count 188
# here is the count 189
# here is the count 190
# here is the count 191
# here is the count 192
# here is the count 193
# here is the count 194
# here is the count 195
# here is the count 196
# here is the count 197
# here is the count 198
# here is the count 199
# here is the count 200
# here is the count 201
# here is the count 202
# here is the count 203
# here is the count 204
# here is the count 205
# here is the count 206
# here is the count 207
# here is the count 208
# here is the count 209
# here is the count 210
# here is the count 211
# here is the count 212
# here is the count 213
# here is the count 214
# here is the count 215
# here is the count 216
# here is the count 217
# here is the count 218
# here is the count 219
# here is the count 220
# here is the count 221
# here is the count 222
# here is the count 223
# here is the count 224
# here is the count 225
# here is the count 226
# here is the count 227
# here is the count 228
# here is the count 229
# here is the count 230
# here is the count 231
# here is the count 232
# here is the count 233
# here is the count 234
# here is the count 235
# here is the count 236
# here is the count 237
# here is the count 238
# here is the count 239
# here is the count 240
# here is the count 241
# here is the count 242
# here is the count 243
# here is the count 244
# here is the count 245
# here is the count 246
# here is the count 247
# here is the count 248
# here is the count 249
# here is the count 250
# here is the count 251
# here is the count 252
# here is the count 253
# here is the count 254
# here is the count 255
# here is the count 256
# here is the count 257
# here is the count 258
# here is the count 259
# here is the count 260
# here is the count 261
# here is the count 262
# here is the count 263
# here is the count 264
# here is the count 265
# here is the count 266
# here is the count 267
# here is the count 268
# here is the count 269
# here is the count 270
# here is the count 271
# here is the count 272
# here is the count 273
# here is the count 274
# here is the count 275
# here is the count 276
# here is the count 277
# here is the count 278
# here is the count 279
# here is the count 280
# here is the count 281
# here is the count 282
# here is the count 283
# here is the count 284
# here is the count 285
# here is the count 286
# here is the count 287
# here is the count 288
# here is the count 289
# here is the count 290
# here is the count 291
# here is the count 292
# here is the count 293
# here is the count 294
# here is the count 295
# here is the count 296
# here is the count 297
# here is the count 298
# here is the count 299
# here is the count 300
# here is the count 301
# here is the count 302
# here is the count 303
# here is the count 304
# here is the count 305
# here is the count 306
# here is the count 307
# here is the count 308
# here is the count 309
# here is the count 310
# here is the count 311
# here is the count 312
# here is the count 313
# here is the count 314
# here is the count 315
# here is the count 316
# here is the count 317
# here is the count 318
# here is the count 319
# here is the count 320
# here is the count 321
# here is the count 322
# here is the count 323
# here is the count 324
# here is the count 325
# here is the count 326
# here is the count 327
# here is the count 328
# here is the count 329
# here is the count 330
# here is the count 331
# here is the count 332
# here is the count 333
# here is the count 334
# here is the count 335
# here is the count 336
# here is the count 337
# here is the count 338
# here is the count 339
# here is the count 340
# here is the count 341
# here is the count 342
# here is the count 343
# here is the count 344
# here is the count 345
# here is the count 346
# here is the count 347
# here is the count 348
# here is the count 349
# here is the count 350
# here is the count 351
# here is the count 352
# here is the count 353
# here is the count 354
# here is the count 355
# here is the count 356
# here is the count 357
# here is the count 358
# here is the count 359
# here is the count 360
# here is the count 361
# here is the count 362
# here is the count 363
# here is the count 364
# here is the count 365
# here is the count 366
# here is the count 367
# here is the count 368
# here is the count 369
# here is the count 370
# here is the count 371
# here is the count 372
# here is the count 373
# here is the count 374
# here is the count 375
# here is the count 376
# here is the count 377
# here is the count 378
# here is the count 379
# here is the count 380
# here is the count 381
# here is the count 382
# here is the count 383
# here is the count 384
# here is the count 385
# here is the count 386
# here is the count 387
# here is the count 388
# here is the count 389
# here is the count 390
# here is the count 391
# here is the count 392
# here is the count 393
# here is the count 394
# here is the count 395
# here is the count 396
# here is the count 397
# here is the count 398
# here is the count 399
# here is the count 400
# here is the count 401
# here is the count 402
# here is the count 403
# here is the count 404
# here is the count 405
# here is the count 406
# here is the count 407
# here is the count 408
# here is the count 409
# here is the count 410
# here is the count 411
# here is the count 412
# here is the count 413
# here is the count 414
# here is the count 415
# here is the count 416
# here is the count 417
# here is the count 418
# here is the count 419
# here is the count 420
# here is the count 421
# here is the count 422
# here is the count 423
# here is the count 424
# here is the count 425
# here is the count 426
# here is the count 427
# here is the count 428
# here is the count 429
# here is the count 430
# here is the count 431
# here is the count 432
# here is the count 433
# here is the count 434
# here is the count 435
# here is the count 436
# here is the count 437
# here is the count 438
# here is the count 439
# here is the count 440
# here is the count 441
# here is the count 442
# here is the count 443
# here is the count 444
# here is the count 445
# here is the count 446
# here is the count 447
# here is the count 448
# here is the count 449
# here is the count 450
# here is the count 451
# here is the count 452
# here is the count 453
# here is the count 454
# here is the count 455
# here is the count 456
# here is the count 457
# here is the count 458
# here is the count 459
# here is the count 460
# here is the count 461
# here is the count 462
# here is the count 463
# here is the count 464
# here is the count 465
# here is the count 466
# here is the count 467
# here is the count 468
# here is the count 469
# here is the count 470
# here is the count 471
# here is the count 472
# here is the count 473
# here is the count 474
# here is the count 475
# here is the count 476
# here is the count 477
# here is the count 478
# here is the count 479
# here is the count 480
# here is the count 481
# here is the count 482
# here is the count 483
# here is the count 484
# here is the count 485
# here is the count 486
# here is the count 487
# here is the count 488
# here is the count 489
# here is the count 490
# here is the count 491
# here is the count 492
# here is the count 493
# here is the count 494
# here is the count 495
# here is the count 496
# here is the count 497
# here is the count 498
# here is the count 499
# here is the count 500
# here is the count 501
# here is the count 502
# here is the count 503
# here is the count 504
# here is the count 505
# here is the count 506
# here is the count 507
# here is the count 508
# here is the count 509
# here is the count 510
# here is the count 511
# here is the count 512
# here is the count 513
# here is the count 514
# here is the count 515
# here is the count 516
# here is the count 517
# here is the count 518
# here is the count 519
# here is the count 520
# here is the count 521
# here is the count 522
# here is the count 523
# here is the count 524
# here is the count 525
# here is the count 526
# here is the count 527
# here is the count 528
# here is the count 529
# here is the count 530
# here is the count 531
# here is the count 532
# here is the count 533
# here is the count 534
# here is the count 535
# here is the count 536
# here is the count 537
# here is the count 538
# here is the count 539
# here is the count 540
# here is the count 541
# here is the count 542
# here is the count 543
# here is the count 544
# here is the count 545
# here is the count 546
# here is the count 547
# here is the count 548
# here is the count 549
# here is the count 550
# here is the count 551
# here is the count 552
# here is the count 553
# here is the count 554
# here is the count 555
# here is the count 556
# here is the count 557
# here is the count 558
# here is the count 559
# here is the count 560
# here is the count 561
# here is the count 562
# here is the count 563
# here is the count 564
# here is the count 565
# here is the count 566
# here is the count 567
# here is the count 568
# here is the count 569
# here is the count 570
# here is the count 571
# here is the count 572
# here is the count 573
# here is the count 574
# here is the count 575
# here is the count 576
# here is the count 577
# here is the count 578
# here is the count 579
# here is the count 580
# here is the count 581
# here is the count 582
# here is the count 583
# here is the count 584
# here is the count 585
# here is the count 586
# here is the count 587
# here is the count 588
# here is the count 589
# here is the count 590
# here is the count 591
# here is the count 592
# here is the count 593
# here is the count 594
# here is the count 595
# here is the count 596
# here is the count 597
# here is the count 598
# here is the count 599
# here is the count 600
# here is the count 601
# here is the count 602
# here is the count 603
# here is the count 604
# here is the count 605
# here is the count 606
# here is the count 607
# here is the count 608
# here is the count 609
# here is the count 610
# here is the count 611
# here is the count 612
# here is the count 613
# here is the count 614
# here is the count 615
# here is the count 616
# here is the count 617
# here is the count 618
# here is the count 619
# here is the count 620
# here is the count 621
# here is the count 622
# here is the count 623
# here is the count 624
# here is the count 625
# here is the count 626
# here is the count 627
# here is the count 628
# here is the count 629
# here is the count 630
# here is the count 631
# here is the count 632
# here is the count 633
# here is the count 634
# here is the count 635
# here is the count 636
# here is the count 637
# here is the count 638
# here is the count 639
# here is the count 640
# here is the count 641
# here is the count 642
# here is the count 643
# here is the count 644
# here is the count 645
# here is the count 646
# here is the count 647
# here is the count 648
# here is the count 649
# here is the count 650
# here is the count 651
# here is the count 652
# here is the count 653
# here is the count 654
# here is the count 655
# here is the count 656
# here is the count 657
# here is the count 658
# here is the count 659
# here is the count 660
# here is the count 661
# here is the count 662
# here is the count 663
# here is the count 664
# here is the count 665
# here is the count 666
# here is the count 667
# here is the count 668
# here is the count 669
# here is the count 670
# here is the count 671
# here is the count 672
# here is the count 673
# here is the count 674
# here is the count 675
# here is the count 676
# here is the count 677
# here is the count 678
# here is the count 679
# here is the count 680
# here is the count 681
# here is the count 682
# here is the count 683
# here is the count 684
# here is the count 685
# here is the count 686
# here is the count 687
# here is the count 688
# here is the count 689
# here is the count 690
# here is the count 691
# here is the count 692
# here is the count 693
# here is the count 694
# here is the count 695
# here is the count 696
# here is the count 697
# here is the count 698
# here is the count 699
# here is the count 700
# here is the count 701
# here is the count 702
# here is the count 703
# here is the count 704
# here is the count 705
# here is the count 706
# here is the count 707
# here is the count 708
# here is the count 709
# here is the count 710
# here is the count 711
# here is the count 712
# here is the count 713
# here is the count 714
# here is the count 715
# here is the count 716
# here is the count 717
# here is the count 718
# here is the count 719
# here is the count 720
# here is the count 721
# here is the count 722
# here is the count 723
# here is the count 724
# here is the count 725
# here is the count 726
# here is the count 727
# here is the count 728
# here is the count 729
# here is the count 730
# here is the count 731
# here is the count 732
# here is the count 733
# here is the count 734
# here is the count 735
# here is the count 736
# here is the count 737
# here is the count 738
# here is the count 739
# here is the count 740
# here is the count 741
# here is the count 742
# here is the count 743
# here is the count 744
# here is the count 745
# here is the count 746
# here is the count 747
# here is the count 748
# here is the count 749
# here is the count 750
# here is the count 751
# here is the count 752
# here is the count 753
# here is the count 754
# here is the count 755
# here is the count 756
# here is the count 757
# here is the count 758
# here is the count 759
# here is the count 760
# here is the count 761
# here is the count 762
# here is the count 763
# here is the count 764
# here is the count 765
# here is the count 766
# here is the count 767
# here is the count 768
# here is the count 769
# here is the count 770
# here is the count 771
# here is the count 772
# here is the count 773
# here is the count 774
# here is the count 775
# here is the count 776
# here is the count 777
# here is the count 778
# here is the count 779
# here is the count 780
# here is the count 781
# here is the count 782
# here is the count 783
# here is the count 784
# here is the count 785
# here is the count 786
# here is the count 787
# here is the count 788
# here is the count 789
# here is the count 790
# here is the count 791
# here is the count 792
# here is the count 793
# here is the count 794
# here is the count 795
# here is the count 796
# here is the count 797
# here is the count 798
# here is the count 799
# here is the count 800
# here is the count 801
# here is the count 802
# here is the count 803
# here is the count 804
# here is the count 805
# here is the count 806
# here is the count 807
# here is the count 808
# here is the count 809
# here is the count 810
# here is the count 811
# here is the count 812
# here is the count 813
# here is the count 814
# here is the count 815
# here is the count 816
# here is the count 817
# here is the count 818
# here is the count 819
# here is the count 820
# here is the count 821
# here is the count 822
# here is the count 823
# here is the count 824
# here is the count 825
# here is the count 826
# here is the count 827
# here is the count 828
# here is the count 829
# here is the count 830
# here is the count 831
# here is the count 832
# here is the count 833
# here is the count 834
# here is the count 835
# here is the count 836
# here is the count 837
# here is the count 838
# here is the count 839
# here is the count 840
# here is the count 841
# here is the count 842
# here is the count 843
# here is the count 844
# here is the count 845
# here is the count 846
# here is the count 847
# here is the count 848
# here is the count 849
# here is the count 850
# here is the count 851
# here is the count 852
# here is the count 853
# here is the count 854
# here is the count 855
# here is the count 856
# here is the count 857
# here is the count 858
# here is the count 859
# here is the count 860
# here is the count 861
# here is the count 862
# here is the count 863
# here is the count 864
# here is the count 865
# here is the count 866
# here is the count 867
# here is the count 868
# here is the count 869
# here is the count 870
# here is the count 871
# here is the count 872
# here is the count 873
# here is the count 874
# here is the count 875
# here is the count 876
# here is the count 877
# here is the count 878
# here is the count 879
# here is the count 880
# here is the count 881
# here is the count 882
# here is the count 883
# here is the count 884
# here is the count 885
# here is the count 886
# here is the count 887
# here is the count 888
# here is the count 889
# here is the count 890
# here is the count 891
# here is the count 892
# here is the count 893
# here is the count 894
# here is the count 895
# here is the count 896
# here is the count 897
# here is the count 898
# here is the count 899
# here is the count 900
# here is the count 901
# here is the count 902
# here is the count 903
# here is the count 904
# here is the count 905
# here is the count 906
# here is the count 907
# here is the count 908
# here is the count 909
# here is the count 910
# here is the count 911
# here is the count 912
# here is the count 913
# here is the count 914
# here is the count 915
# here is the count 916
# here is the count 917
# here is the count 918
# here is the count 919
# here is the count 920
# here is the count 921
# here is the count 922
# here is the count 923
# here is the count 924
# here is the count 925
# here is the count 926
# here is the count 927
# here is the count 928
# here is the count 929
# here is the count 930
# here is the count 931
# here is the count 932
# here is the count 933
# here is the count 934
# here is the count 935
# here is the count 936
# here is the count 937
# here is the count 938
# here is the count 939
# here is the count 940
# here is the count 941
# here is the count 942
# here is the count 943
# here is the count 944
# here is the count 945
# here is the count 946
# here is the count 947
# here is the count 948
# here is the count 949
# here is the count 950
# here is the count 951
# here is the count 952
# here is the count 953
# here is the count 954
# here is the count 955
# here is the count 956
# here is the count 957
# here is the count 958
# here is the count 959
# here is the count 960
# here is the count 961
# here is the count 962
# here is the count 963
# here is the count 964
# here is the count 965
# here is the count 966
# here is the count 967
# here is the count 968
# here is the count 969
# here is the count 970
# here is the count 971
# here is the count 972
# here is the count 973
# here is the count 974
# here is the count 975
# here is the count 976
# here is the count 977
# here is the count 978
# here is the count 979
# here is the count 980
# here is the count 981
# here is the count 982
# here is the count 983
# here is the count 984
# here is the count 985
# here is the count 986
# here is the count 987
# here is the count 988
# here is the count 989
# here is the count 990
# here is the count 991
# here is the count 992
# here is the count 993
# here is the count 994
# here is the count 995
# here is the count 996
# here is the count 997
# here is the count 998
# here is the count 999
# here is the count 1000
# here is the count 1001
# here is the count 1002
# here is the count 1003
# here is the count 1004
# here is the count 1005
# here is the count 1006
# here is the count 1007
# here is the count 1008
# here is the count 1009
# here is the count 1010
# here is the count 1011
# here is the count 1012
# here is the count 1013
# here is the count 1014
# here is the count 1015
# here is the count 1016
# here is the count 1017
# here is the count 1018
# here is the count 1019
# here is the count 1020
# here is the count 1021
# here is the count 1022
# here is the count 1023
# here is the count 1024
# here is the count 1025
# here is the count 1026
# here is the count 1027
# here is the count 1028
# here is the count 1029
# here is the count 1030
# here is the count 1031
# here is the count 1032
# here is the count 1033
# here is the count 1034
# here is the count 1035
# here is the count 1036
# here is the count 1037
# here is the count 1038
# here is the count 1039
# here is the count 1040
# here is the count 1041
# here is the count 1042
# here is the count 1043
# here is the count 1044
# here is the count 1045
# here is the count 1046
# here is the count 1047
# here is the count 1048
# here is the count 1049
# here is the count 1050
# here is the count 1051
# here is the count 1052
# here is the count 1053
# here is the count 1054
# here is the count 1055
# here is the count 1056
# here is the count 1057
# here is the count 1058
# here is the count 1059
# here is the count 1060
# here is the count 1061
# here is the count 1062
# here is the count 1063
# here is the count 1064
# here is the count 1065
# here is the count 1066
# here is the count 1067
# here is the count 1068
# here is the count 1069
# here is the count 1070
# here is the count 1071
# here is the count 1072
# here is the count 1073
# here is the count 1074
# here is the count 1075
# here is the count 1076
# here is the count 1077
# here is the count 1078
# here is the count 1079
# here is the count 1080
# here is the count 1081
# here is the count 1082
# here is the count 1083
# here is the count 1084
# here is the count 1085
# here is the count 1086
# here is the count 1087
# here is the count 1088
# here is the count 1089
# here is the count 1090
# here is the count 1091
# here is the count 1092
# here is the count 1093
# here is the count 1094
# here is the count 1095
# here is the count 1096
# here is the count 1097
# here is the count 1098
# here is the count 1099
# here is the count 1100
# here is the count 1101
# here is the count 1102
# here is the count 1103
# here is the count 1104
# here is the count 1105
# here is the count 1106
# here is the count 1107
# here is the count 1108
# here is the count 1109
# here is the count 1110
# here is the count 1111
# here is the count 1112
# here is the count 1113
# here is the count 1114
# here is the count 1115
# here is the count 1116
# here is the count 1117
# here is the count 1118
# here is the count 1119
# here is the count 1120
# here is the count 1121
# here is the count 1122
# here is the count 1123
# here is the count 1124
# here is the count 1125
# here is the count 1126
# here is the count 1127
# here is the count 1128
# here is the count 1129
# here is the count 1130
# here is the count 1131
# here is the count 1132
# here is the count 1133
# here is the count 1134
# here is the count 1135
# here is the count 1136
# here is the count 1137
# here is the count 1138
# here is the count 1139
# here is the count 1140
# here is the count 1141
# here is the count 1142
# here is the count 1143
# here is the count 1144
# here is the count 1145
# here is the count 1146
# here is the count 1147
# here is the count 1148
# here is the count 1149
# here is the count 1150
# here is the count 1151
# here is the count 1152
# here is the count 1153
# here is the count 1154
# here is the count 1155
# here is the count 1156
# here is the count 1157
# here is the count 1158
# here is the count 1159
# here is the count 1160
# here is the count 1161
# here is the count 1162
# here is the count 1163
# here is the count 1164
# here is the count 1165
# here is the count 1166
# here is the count 1167
# here is the count 1168
# here is the count 1169
# here is the count 1170
# here is the count 1171
# here is the count 1172
# here is the count 1173
# here is the count 1174
# here is the count 1175
# here is the count 1176
# here is the count 1177
# here is the count 1178
# here is the count 1179
# here is the count 1180
# here is the count 1181
# here is the count 1182
# here is the count 1183
# here is the count 1184
# here is the count 1185
# here is the count 1186
# here is the count 1187
# here is the count 1188
# here is the count 1189
# here is the count 1190
# here is the count 1191
# here is the count 1192
# here is the count 1193
# here is the count 1194
# here is the count 1195
# here is the count 1196
# here is the count 1197
# here is the count 1198
# here is the count 1199
# here is the count 1200
# here is the count 1201
# here is the count 1202
# here is the count 1203
# here is the count 1204
# here is the count 1205
# here is the count 1206
# here is the count 1207
# here is the count 1208
# here is the count 1209
# here is the count 1210
# here is the count 1211
# here is the count 1212
# here is the count 1213
# here is the count 1214
# here is the count 1215
# here is the count 1216
# here is the count 1217
# here is the count 1218
# here is the count 1219
# here is the count 1220
# here is the count 1221
# here is the count 1222
# here is the count 1223
# here is the count 1224
# here is the count 1225
# here is the count 1226
# here is the count 1227
# here is the count 1228
# here is the count 1229
# here is the count 1230
# here is the count 1231
# here is the count 1232
# here is the count 1233
# here is the count 1234
# here is the count 1235
# here is the count 1236
# here is the count 1237
# here is the count 1238
# here is the count 1239
# here is the count 1240
# here is the count 1241
# here is the count 1242
# here is the count 1243
# here is the count 1244
# here is the count 1245
# here is the count 1246
# here is the count 1247
# here is the count 1248
# here is the count 1249
# here is the count 1250
# here is the count 1251
# here is the count 1252
# here is the count 1253
# here is the count 1254
# here is the count 1255
# here is the count 1256
# here is the count 1257
# here is the count 1258
# here is the count 1259
# here is the count 1260
# here is the count 1261
# here is the count 1262
# here is the count 1263
# here is the count 1264
# here is the count 1265
# here is the count 1266
# here is the count 1267
# here is the count 1268
# here is the count 1269
# here is the count 1270
# here is the count 1271
# here is the count 1272
# here is the count 1273
# here is the count 1274
# here is the count 1275
# here is the count 1276
# here is the count 1277
# here is the count 1278
# here is the count 1279
# here is the count 1280
# here is the count 1281
# here is the count 1282
# here is the count 1283
# here is the count 1284
# here is the count 1285
# here is the count 1286
# here is the count 1287
# here is the count 1288
# here is the count 1289
# here is the count 1290
# here is the count 1291
# here is the count 1292
# here is the count 1293
# here is the count 1294
# here is the count 1295
# here is the count 1296
# here is the count 1297
# here is the count 1298
# here is the count 1299
# here is the count 1300
# here is the count 1301
# here is the count 1302
# here is the count 1303
# here is the count 1304
# here is the count 1305
# here is the count 1306
# here is the count 1307
# here is the count 1308
# here is the count 1309
# here is the count 1310
# here is the count 1311
# here is the count 1312
# here is the count 1313
# here is the count 1314
# here is the count 1315
# here is the count 1316
# here is the count 1317
# here is the count 1318
# here is the count 1319
# here is the count 1320
# here is the count 1321
# here is the count 1322
# here is the count 1323
# here is the count 1324
# here is the count 1325
# here is the count 1326
# here is the count 1327
# here is the count 1328
# here is the count 1329
# here is the count 1330
# here is the count 1331
# here is the count 1332
# here is the count 1333
# here is the count 1334
# here is the count 1335
# here is the count 1336
# here is the count 1337
# here is the count 1338
# here is the count 1339
# here is the count 1340
# here is the count 1341
# here is the count 1342
# here is the count 1343
# here is the count 1344
# here is the count 1345
# here is the count 1346
# here is the count 1347
# here is the count 1348
# here is the count 1349
# here is the count 1350
# here is the count 1351
# here is the count 1352
# here is the count 1353
# here is the count 1354
# here is the count 1355
# here is the count 1356
# here is the count 1357
# here is the count 1358
# here is the count 1359
# here is the count 1360
# here is the count 1361
# here is the count 1362
# here is the count 1363
# here is the count 1364
# here is the count 1365
# here is the count 1366
# here is the count 1367
# here is the count 1368
# here is the count 1369
# here is the count 1370
# here is the count 1371
# here is the count 1372
# here is the count 1373
# here is the count 1374
# here is the count 1375
# here is the count 1376
# here is the count 1377
# here is the count 1378
# here is the count 1379
# here is the count 1380
# here is the count 1381
# here is the count 1382
# here is the count 1383
# here is the count 1384
# here is the count 1385
# here is the count 1386
# here is the count 1387
# here is the count 1388
# here is the count 1389
# here is the count 1390
# here is the count 1391
# here is the count 1392
# here is the count 1393
# here is the count 1394
# here is the count 1395
# here is the count 1396
# here is the count 1397
# here is the count 1398
# here is the count 1399
# here is the count 1400
# here is the count 1401
# here is the count 1402
# here is the count 1403
# here is the count 1404
# here is the count 1405
# here is the count 1406
# here is the count 1407
# here is the count 1408
# here is the count 1409
# here is the count 1410
# here is the count 1411
# here is the count 1412
# here is the count 1413
# here is the count 1414
# here is the count 1415
# here is the count 1416
# here is the count 1417
# here is the count 1418
# here is the count 1419
# here is the count 1420
# here is the count 1421
# here is the count 1422
# here is the count 1423
# here is the count 1424
# here is the count 1425
# here is the count 1426
# here is the count 1427
# here is the count 1428
# here is the count 1429
# here is the count 1430
# here is the count 1431
# here is the count 1432
# here is the count 1433
# here is the count 1434
# here is the count 1435
# here is the count 1436
# here is the count 1437
# here is the count 1438
# here is the count 1439
# here is the count 1440
# here is the count 1441
# here is the count 1442
# here is the count 1443
# here is the count 1444
# here is the count 1445
# here is the count 1446
# here is the count 1447
# here is the count 1448
# here is the count 1449
# here is the count 1450
# here is the count 1451
# here is the count 1452
# here is the count 1453
# here is the count 1454
# here is the count 1455
# here is the count 1456
# here is the count 1457
# here is the count 1458
# here is the count 1459
# here is the count 1460
# here is the count 1461
# here is the count 1462
# here is the count 1463
# here is the count 1464
# here is the count 1465
# here is the count 1466
# here is the count 1467
# here is the count 1468
# here is the count 1469
# here is the count 1470
# here is the count 1471
# here is the count 1472
# here is the count 1473
# here is the count 1474
# here is the count 1475
# here is the count 1476
# here is the count 1477
# here is the count 1478
# here is the count 1479
# here is the count 1480
# here is the count 1481
# here is the count 1482
# here is the count 1483
# here is the count 1484
# here is the count 1485
# here is the count 1486
# here is the count 1487
# here is the count 1488
# here is the count 1489
# here is the count 1490
# here is the count 1491
# here is the count 1492
# here is the count 1493
# here is the count 1494
# here is the count 1495
# here is the count 1496
# here is the count 1497
# here is the count 1498
# here is the count 1499
# here is the count 1500
# here is the count 1501
# here is the count 1502
# here is the count 1503
# here is the count 1504
# here is the count 1505
# here is the count 1506
# here is the count 1507
# here is the count 1508
# here is the count 1509
# here is the count 1510
# here is the count 1511
# here is the count 1512
# here is the count 1513
# here is the count 1514
# here is the count 1515
# here is the count 1516
# here is the count 1517
# here is the count 1518
# here is the count 1519
# here is the count 1520
# here is the count 1521
# here is the count 1522
# here is the count 1523
# here is the count 1524
# here is the count 1525
# here is the count 1526
# here is the count 1527
# here is the count 1528
# here is the count 1529
# here is the count 1530
# here is the count 1531
# here is the count 1532
# here is the count 1533
# here is the count 1534
# here is the count 1535
# here is the count 1536
# here is the count 1537
# here is the count 1538
# here is the count 1539
# here is the count 1540
# here is the count 1541
# here is the count 1542
# here is the count 1543
# here is the count 1544
# here is the count 1545
# here is the count 1546
# here is the count 1547
# here is the count 1548
# here is the count 1549
# here is the count 1550
# here is the count 1551
# here is the count 1552
# here is the count 1553
# here is the count 1554
# here is the count 1555
# here is the count 1556
# here is the count 1557
# here is the count 1558
# here is the count 1559
# here is the count 1560
# here is the count 1561
# here is the count 1562
# here is the count 1563
# here is the count 1564
# here is the count 1565
# here is the count 1566
# here is the count 1567
# here is the count 1568
# here is the count 1569
# here is the count 1570
# here is the count 1571
# here is the count 1572
# here is the count 1573
# here is the count 1574
# here is the count 1575
# here is the count 1576
# here is the count 1577
# here is the count 1578
# here is the count 1579
# here is the count 1580
# here is the count 1581
# here is the count 1582
# here is the count 1583
# here is the count 1584
# here is the count 1585
# here is the count 1586
# here is the count 1587
# here is the count 1588
# here is the count 1589
# here is the count 1590
# here is the count 1591
# here is the count 1592
# here is the count 1593
# here is the count 1594
# here is the count 1595
# here is the count 1596
# here is the count 1597
# here is the count 1598
# here is the count 1599
# here is the count 1600
# here is the count 1601
# here is the count 1602
# here is the count 1603
# here is the count 1604
# here is the count 1605
# here is the count 1606
# here is the count 1607
# here is the count 1608
# here is the count 1609
# here is the count 1610
# here is the count 1611
# here is the count 1612
# here is the count 1613
# here is the count 1614
# here is the count 1615
# here is the count 1616
# here is the count 1617
# here is the count 1618
# here is the count 1619
# here is the count 1620
# here is the count 1621
# here is the count 1622
# here is the count 1623
# here is the count 1624
# here is the count 1625
# here is the count 1626
# here is the count 1627
# here is the count 1628
# here is the count 1629
# here is the count 1630
# here is the count 1631
# here is the count 1632
# here is the count 1633
# here is the count 1634
# here is the count 1635
# here is the count 1636
# here is the count 1637
# here is the count 1638
# here is the count 1639
# here is the count 1640
# here is the count 1641
# here is the count 1642
# here is the count 1643
# here is the count 1644
# here is the count 1645
# here is the count 1646
# here is the count 1647
# here is the count 1648
# here is the count 1649
# here is the count 1650
# here is the count 1651
# here is the count 1652
# here is the count 1653
# here is the count 1654
# here is the count 1655
# here is the count 1656
# here is the count 1657
# here is the count 1658
# here is the count 1659
# here is the count 1660
# here is the count 1661
# here is the count 1662
# here is the count 1663
# here is the count 1664
# here is the count 1665
# here is the count 1666
# here is the count 1667
# here is the count 1668
# here is the count 1669
# here is the count 1670
# here is the count 1671
# here is the count 1672
# here is the count 1673
# here is the count 1674
# here is the count 1675
# here is the count 1676
# here is the count 1677
# here is the count 1678
# here is the count 1679
# here is the count 1680
# here is the count 1681
# here is the count 1682
# here is the count 1683
# here is the count 1684
# here is the count 1685
# here is the count 1686
# here is the count 1687
# here is the count 1688
# here is the count 1689
# here is the count 1690
# here is the count 1691
# here is the count 1692
# here is the count 1693
# here is the count 1694
# here is the count 1695
# here is the count 1696
# here is the count 1697
# here is the count 1698
# here is the count 1699
# here is the count 1700
# here is the count 1701
# here is the count 1702
# here is the count 1703
# here is the count 1704
# here is the count 1705
# here is the count 1706
# here is the count 1707
# here is the count 1708
# here is the count 1709
# here is the count 1710
# here is the count 1711
# here is the count 1712
# here is the count 1713
# here is the count 1714
# here is the count 1715
# here is the count 1716
# here is the count 1717
# here is the count 1718
# here is the count 1719
# here is the count 1720
# here is the count 1721
# here is the count 1722
# here is the count 1723
# here is the count 1724
# here is the count 1725
# here is the count 1726
# here is the count 1727
# here is the count 1728
# here is the count 1729
# here is the count 1730
# here is the count 1731
# here is the count 1732
# here is the count 1733
# here is the count 1734
# here is the count 1735
# here is the count 1736
# here is the count 1737
# here is the count 1738
# here is the count 1739
# here is the count 1740
# here is the count 1741
# here is the count 1742
# here is the count 1743
# here is the count 1744
# here is the count 1745
# here is the count 1746
# here is the count 1747
# here is the count 1748
# here is the count 1749
# here is the count 1750
# here is the count 1751
# here is the count 1752
# here is the count 1753
# here is the count 1754
# here is the count 1755
# here is the count 1756
# here is the count 1757
# here is the count 1758
# here is the count 1759
# here is the count 1760
# here is the count 1761
# here is the count 1762
# here is the count 1763
# here is the count 1764
# here is the count 1765
# here is the count 1766
# here is the count 1767
# here is the count 1768
# here is the count 1769
# here is the count 1770
# here is the count 1771
# here is the count 1772
# here is the count 1773
# here is the count 1774
# here is the count 1775
# here is the count 1776
# here is the count 1777
# here is the count 1778
# here is the count 1779
# here is the count 1780
# here is the count 1781
# here is the count 1782
# here is the count 1783
# here is the count 1784
# here is the count 1785
# here is the count 1786
# here is the count 1787
# here is the count 1788
# here is the count 1789
# here is the count 1790
# here is the count 1791
# here is the count 1792
# here is the count 1793
# here is the count 1794
# here is the count 1795
# here is the count 1796
# here is the count 1797
# here is the count 1798
# here is the count 1799
# here is the count 1800
# here is the count 1801
# here is the count 1802
# here is the count 1803
# here is the count 1804
# here is the count 1805
# here is the count 1806
# here is the count 1807
# here is the count 1808
# here is the count 1809
# here is the count 1810
# here is the count 1811
# here is the count 1812
# here is the count 1813
# here is the count 1814
# here is the count 1815
# here is the count 1816
# here is the count 1817
# here is the count 1818
# here is the count 1819
# here is the count 1820
# here is the count 1821
# here is the count 1822
# here is the count 1823
# here is the count 1824
# here is the count 1825
# here is the count 1826
# here is the count 1827
# here is the count 1828
# here is the count 1829
# here is the count 1830
# here is the count 1831
# here is the count 1832
# here is the count 1833
# here is the count 1834
# here is the count 1835
# here is the count 1836
# here is the count 1837
# here is the count 1838
# here is the count 1839
# here is the count 1840
# here is the count 1841
# here is the count 1842
# here is the count 1843
# here is the count 1844
# here is the count 1845
# here is the count 1846
# here is the count 1847
# here is the count 1848
# here is the count 1849
# here is the count 1850
# here is the count 1851
# here is the count 1852
# here is the count 1853
# here is the count 1854
# here is the count 1855
# here is the count 1856
# here is the count 1857
# here is the count 1858
# here is the count 1859
# here is the count 1860
# here is the count 1861
# here is the count 1862
# here is the count 1863
# here is the count 1864
# here is the count 1865
# here is the count 1866
# here is the count 1867
# here is the count 1868
# here is the count 1869
# here is the count 1870
# here is the count 1871
# here is the count 1872
# here is the count 1873
# here is the count 1874
# here is the count 1875
# here is the count 1876
# here is the count 1877
# here is the count 1878
# here is the count 1879
# here is the count 1880
# here is the count 1881
# here is the count 1882
# here is the count 1883
# here is the count 1884
# here is the count 1885
# here is the count 1886
# here is the count 1887
# here is the count 1888
# here is the count 1889
# here is the count 1890
# here is the count 1891
# here is the count 1892
# here is the count 1893
# here is the count 1894
# here is the count 1895
# here is the count 1896
# here is the count 1897
# here is the count 1898
# here is the count 1899
# here is the count 1900
# here is the count 1901
# here is the count 1902
# here is the count 1903
# here is the count 1904
# here is the count 1905
# here is the count 1906
# here is the count 1907
# here is the count 1908
# here is the count 1909
# here is the count 1910
# here is the count 1911
# here is the count 1912
# here is the count 1913
# here is the count 1914
# here is the count 1915
# here is the count 1916
# here is the count 1917
# here is the count 1918
# here is the count 1919
# here is the count 1920
# here is the count 1921
# here is the count 1922
# here is the count 1923
# here is the count 1924
# here is the count 1925
# here is the count 1926
# here is the count 1927
# here is the count 1928
# here is the count 1929
# here is the count 1930
# here is the count 1931
# here is the count 1932
# here is the count 1933
# here is the count 1934
# here is the count 1935
# here is the count 1936
# here is the count 1937
# here is the count 1938
# here is the count 1939
# here is the count 1940
# here is the count 1941
# here is the count 1942
# here is the count 1943
# here is the count 1944
# here is the count 1945
# here is the count 1946
# here is the count 1947
# here is the count 1948
# here is the count 1949
# here is the count 1950
# here is the count 1951
# here is the count 1952
# here is the count 1953
# here is the count 1954
# here is the count 1955
# here is the count 1956
# here is the count 1957
# here is the count 1958
# here is the count 1959
# here is the count 1960
# here is the count 1961
# here is the count 1962
# here is the count 1963
# here is the count 1964
# here is the count 1965
# here is the count 1966
# here is the count 1967
# here is the count 1968
# here is the count 1969
# here is the count 1970
# here is the count 1971
# here is the count 1972
# here is the count 1973
# here is the count 1974
# here is the count 1975
# here is the count 1976
# here is the count 1977
# here is the count 1978
# here is the count 1979
# here is the count 1980
# here is the count 1981
# here is the count 1982
# here is the count 1983
# here is the count 1984
# here is the count 1985
# here is the count 1986
# here is the count 1987
# here is the count 1988
# here is the count 1989
# here is the count 1990
# here is the count 1991
# here is the count 1992
# here is the count 1993
# here is the count 1994
# here is the count 1995
# here is the count 1996
# here is the count 1997
# here is the count 1998
# here is the count 1999
# here is the count 2000
# here is the count 2001
# here is the count 2002
# here is the count 2003
# here is the count 2004
# here is the count 2005
# here is the count 2006
# here is the count 2007
# here is the count 2008
# here is the count 2009
# here is the count 2010
# here is the count 2011
# here is the count 2012
# here is the count 2013
# here is the count 2014
# here is the count 2015
# here is the count 2016
# here is the count 2017
# here is the count 2018
# here is the count 2019
# here is the count 2020
# here is the count 2021
# here is the count 2022
# here is the count 2023
# here is the count 2024
# here is the count 2025
# here is the count 2026
# here is the count 2027
# here is the count 2028
# here is the count 2029
# here is the count 2030
# here is the count 2031
# here is the count 2032
# here is the count 2033
# here is the count 2034
# here is the count 2035
# here is the count 2036
# here is the count 2037
# here is the count 2038
# here is the count 2039
# here is the count 2040
# here is the count 2041
# here is the count 2042
# here is the count 2043
# here is the count 2044
# here is the count 2045
# here is the count 2046
# here is the count 2047
# here is the count 2048
# here is the count 2049
# here is the count 2050
# here is the count 2051
# here is the count 2052
# here is the count 2053
# here is the count 2054
# here is the count 2055
# here is the count 2056
# here is the count 2057
# here is the count 2058
# here is the count 2059
# here is the count 2060
# here is the count 2061
# here is the count 2062
# here is the count 2063
# here is the count 2064
# here is the count 2065
# here is the count 2066
# here is the count 2067
# here is the count 2068
# here is the count 2069
# here is the count 2070
# here is the count 2071
# here is the count 2072
# here is the count 2073
# here is the count 2074
# here is the count 2075
# here is the count 2076
# here is the count 2077
# here is the count 2078
# here is the count 2079
# here is the count 2080
# here is the count 2081
# here is the count 2082
# here is the count 2083
# here is the count 2084
# here is the count 2085
# here is the count 2086
# here is the count 2087
# here is the count 2088
# here is the count 2089
# here is the count 2090
# here is the count 2091
# here is the count 2092
# here is the count 2093
# here is the count 2094
# here is the count 2095
# here is the count 2096
# here is the count 2097
# here is the count 2098
# here is the count 2099
# here is the count 2100
# here is the count 2101
# here is the count 2102
# here is the count 2103
# here is the count 2104
# here is the count 2105
# here is the count 2106
# here is the count 2107
# here is the count 2108
# here is the count 2109
# here is the count 2110
# here is the count 2111
# here is the count 2112
# here is the count 2113
# here is the count 2114
# here is the count 2115
# here is the count 2116
# here is the count 2117
# here is the count 2118
# here is the count 2119
# here is the count 2120
# here is the count 2121
# here is the count 2122
# here is the count 2123
# here is the count 2124
# here is the count 2125
# here is the count 2126
# here is the count 2127
# here is the count 2128
# here is the count 2129
# here is the count 2130
# here is the count 2131
# here is the count 2132
# here is the count 2133
# here is the count 2134
# ...
# here is the count 11726
# here is the count 11727
# here is the count 11728
# here is the count 11729
# here is the count 11730
# here is the count 11731
# here is the count 11732
# here is the count 11733
# here is the count 11734
# here is the count 11735
# here is the count 11736
# here is the count 11737
# here is the count 11738
# here is the count 11739
# here is the count 11740
# here is the count 11741
# here is the count 11742
# here is the count 11743
# here is the count 11744
# here is the count 11745
# here is the count 11746
# here is the count 11747
# here is the count 11748
# here is the count 11749
# here is the count 11750
# here is the count 11751
# here is the count 11752
# here is the count 11753
# here is the count 11754
# here is the count 11755
# here is the count 11756
# here is the count 11757
# here is the count 11758
# here is the count 11759
# here is the count 11760
# here is the count 11761
# here is the count 11762
# here is the count 11763
# here is the count 11764
# here is the count 11765
# here is the count 11766
# here is the count 11767
# here is the count 11768
# here is the count 11769
# here is the count 11770
# here is the count 11771
# here is the count 11772
# here is the count 11773
# here is the count 11774
# here is the count 11775
# here is the count 11776
# here is the count 11777
# here is the count 11778
# here is the count 11779
# here is the count 11780
# here is the count 11781
# here is the count 11782
# here is the count 11783
# here is the count 11784
# here is the count 11785
# here is the count 11786
# here is the count 11787
# here is the count 11788
# here is the count 11789
# here is the count 11790
# here is the count 11791
# here is the count 11792
# here is the count 11793
# here is the count 11794
# here is the count 11795
# here is the count 11796
# here is the count 11797
# here is the count 11798
# here is the count 11799
# here is the count 11800
# here is the count 11801
# here is the count 11802
# here is the count 11803
# here is the count 11804
# here is the count 11805
# here is the count 11806
# here is the count 11807
# here is the count 11808
# here is the count 11809
# here is the count 11810
# here is the count 11811
# here is the count 11812
# here is the count 11813
# here is the count 11814
# here is the count 11815
# here is the count 11816
# here is the count 11817
# here is the count 11818
# here is the count 11819
# here is the count 11820
# here is the count 11821
# here is the count 11822
# here is the count 11823
# here is the count 11824
# here is the count 11825
# here is the count 11826
# here is the count 11827
# here is the count 11828
# here is the count 11829
# here is the count 11830
# here is the count 11831
# here is the count 11832
# here is the count 11833
# here is the count 11834
# here is the count 11835
# here is the count 11836
# here is the count 11837
# here is the count 11838
# here is the count 11839
# here is the count 11840
# here is the count 11841
# here is the count 11842
# here is the count 11843
# here is the count 11844
# here is the count 11845
# here is the count 11846
# here is the count 11847
# here is the count 11848
# here is the count 11849
# here is the count 11850
# here is the count 11851
# here is the count 11852
# here is the count 11853
# here is the count 11854
# here is the count 11855
# here is the count 11856
# here is the count 11857
# here is the count 11858
# here is the count 11859
# here is the count 11860
# here is the count 11861
# here is the count 11862
# here is the count 11863
# here is the count 11864
# here is the count 11865
# here is the count 11866
# here is the count 11867
# here is the count 11868
# here is the count 11869
# here is the count 11870
# here is the count 11871
# here is the count 11872
# here is the count 11873
# here is the count 11874
# here is the count 11875
# here is the count 11876
# here is the count 11877
# here is the count 11878
# here is the count 11879
# here is the count 11880
# here is the count 11881
# here is the count 11882
# here is the count 11883
# here is the count 11884
# here is the count 11885
# here is the count 11886
# here is the count 11887
# here is the count 11888
# here is the count 11889
# here is the count 11890
# here is the count 11891
# here is the count 11892
# here is the count 11893
# here is the count 11894
# here is the count 11895
# here is the count 11896
# here is the count 11897
# here is the count 11898
# here is the count 11899
# here is the count 11900
# here is the count 11901
# here is the count 11902
# here is the count 11903
# here is the count 11904
# here is the count 11905
# here is the count 11906
# here is the count 11907
# here is the count 11908
# here is the count 11909
# here is the count 11910
# here is the count 11911
# here is the count 11912
# here is the count 11913
# here is the count 11914
# here is the count 11915
# here is the count 11916
# here is the count 11917
# here is the count 11918
# here is the count 11919
# here is the count 11920
# here is the count 11921
# here is the count 11922
# here is the count 11923
# here is the count 11924
# here is the count 11925
# here is the count 11926
# here is the count 11927
# here is the count 11928
# here is the count 11929
# here is the count 11930
# here is the count 11931
# here is the count 11932
# here is the count 11933
# here is the count 11934
# here is the count 11935
# here is the count 11936
# here is the count 11937
# here is the count 11938
# here is the count 11939
# here is the count 11940
# here is the count 11941
# here is the count 11942
# here is the count 11943
# here is the count 11944
# here is the count 11945
# here is the count 11946
# here is the count 11947
# here is the count 11948
# here is the count 11949
# here is the count 11950
# here is the count 11951
# here is the count 11952
# here is the count 11953
# here is the count 11954
# here is the count 11955
# here is the count 11956
# here is the count 11957
# here is the count 11958
# here is the count 11959
# here is the count 11960
# here is the count 11961
# here is the count 11962
# here is the count 11963
# here is the count 11964
# here is the count 11965
# here is the count 11966
# here is the count 11967
# here is the count 11968
# here is the count 11969
# here is the count 11970
# here is the count 11971
# here is the count 11972
# here is the count 11973
# here is the count 11974
# here is the count 11975
# here is the count 11976
# here is the count 11977
# here is the count 11978
# here is the count 11979
# here is the count 11980
# here is the count 11981
# here is the count 11982
# here is the count 11983
# here is the count 11984
# here is the count 11985
# here is the count 11986
# here is the count 11987
# here is the count 11988
# here is the count 11989
# here is the count 11990
# here is the count 11991
# here is the count 11992
# here is the count 11993
# here is the count 11994
# here is the count 11995
# here is the count 11996
# here is the count 11997
# here is the count 11998
# here is the count 11999
# here is the count 12000
# here is the count 12001
# here is the count 12002
# here is the count 12003
# here is the count 12004
# here is the count 12005
# here is the count 12006
# here is the count 12007
# here is the count 12008
# here is the count 12009
# here is the count 12010
# here is the count 12011
# here is the count 12012
# here is the count 12013
# here is the count 12014
# here is the count 12015
# here is the count 12016
# here is the count 12017
# here is the count 12018
# here is the count 12019
# here is the count 12020
# here is the count 12021
# here is the count 12022
# here is the count 12023
# here is the count 12024
# here is the count 12025
# here is the count 12026
# here is the count 12027
# here is the count 12028
# here is the count 12029
# here is the count 12030
# here is the count 12031
# here is the count 12032
# here is the count 12033
# here is the count 12034
# here is the count 12035
# here is the count 12036
# here is the count 12037
# here is the count 12038
# here is the count 12039
# here is the count 12040
# here is the count 12041
# here is the count 12042
# here is the count 12043
# here is the count 12044
# here is the count 12045
# here is the count 12046
# here is the count 12047
# here is the count 12048
# here is the count 12049
# here is the count 12050
# here is the count 12051
# here is the count 12052
# here is the count 12053
# here is the count 12054
# here is the count 12055
# here is the count 12056
# here is the count 12057
# here is the count 12058
# here is the count 12059
# here is the count 12060
# here is the count 12061
# here is the count 12062
# here is the count 12063
# here is the count 12064
# here is the count 12065
# here is the count 12066
# here is the count 12067
# here is the count 12068
# here is the count 12069
# here is the count 12070
# here is the count 12071
# here is the count 12072
# here is the count 12073
# here is the count 12074
# here is the count 12075
# here is the count 12076
# here is the count 12077
# here is the count 12078
# here is the count 12079
# here is the count 12080
# here is the count 12081
# here is the count 12082
# here is the count 12083
# here is the count 12084
# here is the count 12085
# here is the count 12086
# here is the count 12087
# here is the count 12088
# here is the count 12089
# here is the count 12090
# here is the count 12091
# here is the count 12092
# here is the count 12093
# here is the count 12094
# here is the count 12095
# here is the count 12096
# here is the count 12097
# here is the count 12098
# here is the count 12099
# here is the count 12100
# here is the count 12101
# here is the count 12102
# here is the count 12103
# here is the count 12104
# here is the count 12105
# here is the count 12106
# here is the count 12107
# here is the count 12108
# here is the count 12109
# here is the count 12110
# here is the count 12111
# here is the count 12112
# here is the count 12113
# here is the count 12114
# here is the count 12115
# here is the count 12116
# here is the count 12117
# here is the count 12118
# here is the count 12119
# here is the count 12120
# here is the count 12121
# here is the count 12122
# here is the count 12123
# here is the count 12124
# here is the count 12125
# here is the count 12126
# here is the count 12127
# here is the count 12128
# here is the count 12129
# here is the count 12130
# here is the count 12131
# here is the count 12132
# here is the count 12133
# here is the count 12134
# here is the count 12135
# here is the count 12136
# here is the count 12137
# here is the count 12138
# here is the count 12139
# here is the count 12140
# here is the count 12141
# here is the count 12142
# here is the count 12143
# here is the count 12144
# here is the count 12145
# here is the count 12146
# here is the count 12147
# here is the count 12148
# here is the count 12149
# here is the count 12150
# here is the count 12151
# here is the count 12152
# here is the count 12153
# here is the count 12154
# here is the count 12155
# here is the count 12156
# here is the count 12157
# here is the count 12158
# here is the count 12159
# here is the count 12160
# here is the count 12161
# here is the count 12162
# here is the count 12163
# here is the count 12164
# here is the count 12165
# here is the count 12166
# here is the count 12167
# here is the count 12168
# here is the count 12169
# here is the count 12170
# here is the count 12171
# here is the count 12172
# here is the count 12173
# here is the count 12174
# here is the count 12175
# here is the count 12176
# here is the count 12177
# here is the count 12178
# here is the count 12179
# here is the count 12180
# here is the count 12181
# here is the count 12182
# here is the count 12183
# here is the count 12184
# here is the count 12185
# here is the count 12186
# here is the count 12187
# here is the count 12188
# here is the count 12189
# here is the count 12190
# here is the count 12191
# here is the count 12192
# here is the count 12193
# here is the count 12194
# here is the count 12195
# here is the count 12196
# here is the count 12197
# here is the count 12198
# here is the count 12199
# here is the count 12200
# here is the count 12201
# here is the count 12202
# here is the count 12203
# here is the count 12204
# here is the count 12205
# here is the count 12206
# here is the count 12207
# here is the count 12208
# here is the count 12209
# here is the count 12210
# here is the count 12211
# here is the count 12212
# here is the count 12213
# here is the count 12214
# here is the count 12215
# here is the count 12216
# here is the count 12217
# here is the count 12218
# here is the count 12219
# here is the count 12220
# here is the count 12221
# here is the count 12222
# here is the count 12223
# here is the count 12224
# here is the count 12225
# here is the count 12226
# here is the count 12227
# here is the count 12228
# here is the count 12229
# here is the count 12230
# here is the count 12231
# here is the count 12232
# here is the count 12233
# here is the count 12234
# here is the count 12235
# here is the count 12236
# here is the count 12237
# here is the count 12238
# here is the count 12239
# here is the count 12240
# here is the count 12241
# here is the count 12242
# here is the count 12243
# here is the count 12244
# here is the count 12245
# here is the count 12246
# here is the count 12247
# here is the count 12248
# here is the count 12249
# here is the count 12250
# here is the count 12251
# here is the count 12252
# here is the count 12253
# here is the count 12254
# here is the count 12255
# here is the count 12256
# here is the count 12257
# here is the count 12258
# here is the count 12259
# here is the count 12260
# here is the count 12261
# here is the count 12262
# here is the count 12263
# here is the count 12264
# here is the count 12265
# here is the count 12266
# here is the count 12267
# here is the count 12268
# here is the count 12269
# here is the count 12270
# here is the count 12271
# here is the count 12272
# here is the count 12273
# here is the count 12274
# here is the count 12275
# here is the count 12276
# here is the count 12277
# here is the count 12278
# here is the count 12279
# here is the count 12280
# here is the count 12281
# here is the count 12282
# here is the count 12283
# here is the count 12284
# here is the count 12285
# here is the count 12286
# here is the count 12287
# here is the count 12288
# here is the count 12289
# here is the count 12290
# here is the count 12291
# here is the count 12292
# here is the count 12293
# here is the count 12294
# here is the count 12295
# here is the count 12296
# here is the count 12297
# here is the count 12298
# here is the count 12299
# here is the count 12300
# here is the count 12301
# here is the count 12302
# here is the count 12303
# here is the count 12304
# here is the count 12305
# here is the count 12306
# here is the count 12307
# here is the count 12308
# here is the count 12309
# here is the count 12310
# here is the count 12311
# here is the count 12312
# here is the count 12313
# here is the count 12314
# here is the count 12315
# here is the count 12316
# here is the count 12317
# here is the count 12318
# here is the count 12319
# here is the count 12320
# here is the count 12321
# here is the count 12322
# here is the count 12323
# here is the count 12324
# here is the count 12325
# here is the count 12326
# here is the count 12327
# here is the count 12328
# here is the count 12329
# here is the count 12330
# here is the count 12331
# here is the count 12332
# here is the count 12333
# here is the count 12334
# here is the count 12335
# here is the count 12336
# here is the count 12337
# here is the count 12338
# here is the count 12339
# here is the count 12340
# here is the count 12341
# here is the count 12342
# here is the count 12343
# here is the count 12344
# here is the count 12345
# here is the count 12346
# here is the count 12347
# here is the count 12348
# here is the count 12349
# here is the count 12350
# here is the count 12351
# here is the count 12352
# here is the count 12353
# here is the count 12354
# here is the count 12355
# here is the count 12356
# here is the count 12357
# here is the count 12358
# here is the count 12359
# here is the count 12360
# here is the count 12361
# here is the count 12362
# here is the count 12363
# here is the count 12364
# here is the count 12365
# here is the count 12366
# here is the count 12367
# here is the count 12368
# here is the count 12369
# here is the count 12370
# here is the count 12371
# here is the count 12372
# here is the count 12373
# here is the count 12374
# here is the count 12375
# here is the count 12376
# here is the count 12377
# here is the count 12378
# here is the count 12379
# here is the count 12380
# here is the count 12381
# here is the count 12382
# here is the count 12383
# here is the count 12384
# here is the count 12385
# here is the count 12386
# here is the count 12387
# here is the count 12388
# here is the count 12389
# here is the count 12390
# here is the count 12391

# %%
data[data["name"] == "Airbnb"][["uuid","name"]].values
# Out:
# array([['bcb617c3-9e43-d5b0-1d14-82b795f2642f', 'Airbnb']], dtype=object)

# %%
travel_companies_ls.values[2526]
# Out:
# array(['20cf3f7e-c5fd-aa4b-d81d-2b0bc4f355d6', 'PixieWorks'], dtype=object)

# %%
results = collection.find({"name_a":"Airbnb"})
ls = list(results)

# %%
result_data = pd.DataFrame(sorted(ls, key=lambda x: x.get("similarity"), reverse = True))

# %%
new_data = data[["name","description","p_description"]]

# %%
new_data.columns = ["name_b","description","p_description"]

# %%
merge = pd.merge(result_data,new_data,how = "left",on = ["name_b"])

# %%
merge.head(20).to_excel("baseline.xlsx",index=False)

# %%
ls = list(results)

# %%
pd.DataFrame(ls)
# Out:
#                          _id                                  id_a  \
# 0   60f44c1d55de66abdf6659c4  e1393508-30ea-8a36-3f96-dd3226033abd
# 1   60f44c1d55de66abdf6659c5  e1393508-30ea-8a36-3f96-dd3226033abd
# 2   60f44c1d55de66abdf6659c6  e1393508-30ea-8a36-3f96-dd3226033abd
# 3   60f44c1d55de66abdf6659c7  e1393508-30ea-8a36-3f96-dd3226033abd
# 4   60f44c1e55de66abdf6659c8  e1393508-30ea-8a36-3f96-dd3226033abd
# 5   60f44c1e55de66abdf6659c9  e1393508-30ea-8a36-3f96-dd3226033abd
# 6   60f44c1e55de66abdf6659ca  e1393508-30ea-8a36-3f96-dd3226033abd
# 7   60f44c1e55de66abdf6659cb  e1393508-30ea-8a36-3f96-dd3226033abd
# 8   60f44c1e55de66abdf6659cc  e1393508-30ea-8a36-3f96-dd3226033abd
# 9   60f44c1e55de66abdf6659cd  e1393508-30ea-8a36-3f96-dd3226033abd
# 10  60f44c4955de66abdf6659d7  e1393508-30ea-8a36-3f96-dd3226033abd
# 11  60f44c4955de66abdf6659d8  e1393508-30ea-8a36-3f96-dd3226033abd
# 12  60f44c4955de66abdf6659d9  e1393508-30ea-8a36-3f96-dd3226033abd
# 13  60f44c4955de66abdf6659da  e1393508-30ea-8a36-3f96-dd3226033abd
# 14  60f44c4955de66abdf6659db  e1393508-30ea-8a36-3f96-dd3226033abd
# 15  60f44c4955de66abdf6659dc  e1393508-30ea-8a36-3f96-dd3226033abd
# 16  60f44c4a55de66abdf6659dd  e1393508-30ea-8a36-3f96-dd3226033abd
# 17  60f44c4a55de66abdf6659de  e1393508-30ea-8a36-3f96-dd3226033abd
# 18  60f44c4a55de66abdf6659df  e1393508-30ea-8a36-3f96-dd3226033abd
# 19  60f44c4a55de66abdf6659e0  e1393508-30ea-8a36-3f96-dd3226033abd
#
#                                     id_b    name_a                name_b  \
# 0   2471be1a-bd57-ef58-22b8-e7dc7266039e  Wetpaint                TripUp
# 1   b62feb13-991c-2ae7-8faa-0b96d9a69ec6  Wetpaint              SideStep
# 2   5c6f4d9e-dc72-e018-ee21-71cd23f698ad  Wetpaint              Farecast
# 3   b5f351ca-6fc1-3661-e3fb-a498ce4b1a47  Wetpaint                 Yapta
# 4   c37e4ed6-f214-08ab-338a-33f329cffe3f  Wetpaint               TripHub
# 5   a0f5e737-d973-703c-7f66-0fc31d0e4b5b  Wetpaint                TVtrip
# 6   31f9d866-3660-5367-8c52-028a7610e441  Wetpaint          Hotelicopter
# 7   9149ba81-8e61-1ffb-1ef8-66573435e720  Wetpaint                Sulake
# 8   b915e540-3377-6a2a-651e-6fd7c0787e26  Wetpaint                   TCV
# 9   d2712549-89f1-0f55-4ac9-c220f4772ff8  Wetpaint  lastminute.com group
# 10  2471be1a-bd57-ef58-22b8-e7dc7266039e  Wetpaint                TripUp
# 11  b62feb13-991c-2ae7-8faa-0b96d9a69ec6  Wetpaint              SideStep
# 12  5c6f4d9e-dc72-e018-ee21-71cd23f698ad  Wetpaint              Farecast
# 13  b5f351ca-6fc1-3661-e3fb-a498ce4b1a47  Wetpaint                 Yapta
# 14  c37e4ed6-f214-08ab-338a-33f329cffe3f  Wetpaint               TripHub
# 15  a0f5e737-d973-703c-7f66-0fc31d0e4b5b  Wetpaint                TVtrip
# 16  31f9d866-3660-5367-8c52-028a7610e441  Wetpaint          Hotelicopter
# 17  9149ba81-8e61-1ffb-1ef8-66573435e720  Wetpaint                Sulake
# 18  b915e540-3377-6a2a-651e-6fd7c0787e26  Wetpaint                   TCV
# 19  d2712549-89f1-0f55-4ac9-c220f4772ff8  Wetpaint  lastminute.com group
#
#     similarity
# 0     0.775270
# 1     0.876184
# 2     0.841621
# 3     0.743773
# 4     0.847277
# 5     0.840842
# 6     0.866531
# 7     0.878306
# 8     0.829159
# 9     0.811847
# 10    0.775270
# 11    0.876184
# 12    0.841621
# 13    0.743773
# 14    0.847277
# 15    0.840842
# 16    0.866531
# 17    0.878306
# 18    0.829159
# 19    0.811847
