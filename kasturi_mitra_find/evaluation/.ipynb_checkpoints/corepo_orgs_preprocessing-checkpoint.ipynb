# %%
import pandas as pd
import pycountry

# %%
corepo_orgs = pd.read_csv('../techcrunch_scrape/corepo_lookup_structured.csv', index_col=0)
corepo_orgs
# Out:
#       article_id                 search_keyword  \
# 0              0                         FamPay
# 1              1  Ontario Teachers Pension Plan
# 2              1  Ontario Teachers Pension Plan
# 3              1  Ontario Teachers Pension Plan
# 4              1  Ontario Teachers Pension Plan
# ...          ...                            ...
# 9653         499                     Copenhagen
# 9654         499                     Copenhagen
# 9655         499                     Copenhagen
# 9656         499                     Copenhagen
# 9657         499                     Copenhagen
#
#                                        name  \
# 0                                    FamPay
# 1            Ontario Teachers' Pension Plan
# 2     Cadillac Fairview Corporation Limited
# 3         Canadian Tire Corporation Limited
# 4         Maple Leaf Sports & Entertainment
# ...                                     ...
# 9653                            Siteimprove
# ...

# %%
# remove any duplicates
corepo_orgs = corepo_orgs.drop_duplicates()
corepo_orgs
# Out:
#       article_id                 search_keyword  \
# 0              0                         FamPay
# 1              1  Ontario Teachers Pension Plan
# 2              1  Ontario Teachers Pension Plan
# 3              1  Ontario Teachers Pension Plan
# 4              1  Ontario Teachers Pension Plan
# ...          ...                            ...
# 9653         499                     Copenhagen
# 9654         499                     Copenhagen
# 9655         499                     Copenhagen
# 9656         499                     Copenhagen
# 9657         499                     Copenhagen
#
#                                        name  \
# 0                                    FamPay
# 1            Ontario Teachers' Pension Plan
# 2     Cadillac Fairview Corporation Limited
# 3         Canadian Tire Corporation Limited
# 4         Maple Leaf Sports & Entertainment
# ...                                     ...
# 9653                            Siteimprove
# ...

# %%
cb_data = pd.read_csv('organizations_trimmed.csv', index_col=0)
cb_data
# Out:
# e:\university\dissertation\code\dissertations-2021-info\kasturi_mitra_find\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                                          uuid                   name  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd               Wetpaint
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                   Zoho
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                   Digg
# 3        f4d5ab44-058b-298b-ea81-380e6e9a8eec        Omidyar Network
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb               Facebook
# ...                                       ...                    ...
# 1216440  09c8e895-e62e-46f0-93f9-45e088ede007                AngelNV
# 1216441  9b7c50d5-8d96-4af4-9b0e-af72705184e9      Science Delivered
# 1216442  98589112-e90c-434b-a4e7-ffaa12eee602              OmniPanel
# ...

# %%
print(corepo_orgs['employee_count'].unique())
print(cb_data['employee_count'].unique())
# Out:
# ['51 - 200' '1,001 - 5,000' '10,000 or more' '501 - 1,000' '201 - 500' nan
#  '5,001 - 10,000' '1 - 50']
# ['51-100' '1001-5000' '101-250' '10000+' '11-50' '1-10' 'unknown'
#  '251-500' '501-1000' '5001-10000']

# %%
corepo_orgs['employee_count'] = corepo_orgs['employee_count'].str.replace(",", "")
corepo_orgs['employee_count'] = corepo_orgs['employee_count'].str.replace(" - ", "-")
corepo_orgs['employee_count'] = corepo_orgs['employee_count'].str.replace(" or more", "+")
print(corepo_orgs['employee_count'].unique())
# Out:
# ['51-200' '1001-5000' '10000+' '501-1000' '201-500' nan '5001-10000'
#  '1-50']
# C:\Users\KASTUR~1\AppData\Local\Temp/ipykernel_19592/4253126491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corepo_orgs['employee_count'] = corepo_orgs['employee_count'].str.replace(",", "")
# C:\Users\KASTUR~1\AppData\Local\Temp/ipykernel_19592/4253126491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corepo_orgs['employee_count'] = corepo_orgs['employee_count'].str.replace(" - ", "-")
# ...
