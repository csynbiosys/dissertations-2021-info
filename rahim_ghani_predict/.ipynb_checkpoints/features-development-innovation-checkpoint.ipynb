# %%
#Import basic packages
import os
import numpy as np
import pandas as pd
import csv
import regex as re
import datetime as dt

# %%
#import outcome file with org_uuid
main_df = pd.read_csv(R"d:/msc-project/data/final/outcome_final.csv",encoding='utf-8',
                         index_col='org_uuid',
                         parse_dates= ['founded_on','seed_date','series_a_date','series_b_date','series_c_date'])
main_processing_df = main_df[['name','outcome']]

# %%
main_df.head(3)
# Out:
#                                                               name     status  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                       Resilio  operating
# 00002470-bff7-6226-5800-0ca1b3787b6f                    Codementor  operating
# 000095de-8e2b-82f1-32a7-c222ba3d5682  Ultraprise Loan Technologies  operating
#
#                                      founded_on  seed_date series_a_date  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119 2016-11-01        NaT           NaT
# 00002470-bff7-6226-5800-0ca1b3787b6f 2013-01-01 2013-08-05           NaT
# 000095de-8e2b-82f1-32a7-c222ba3d5682 2001-01-01        NaT           NaT
#
#                                      series_b_date series_c_date  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119           NaT           NaT
# 00002470-bff7-6226-5800-0ca1b3787b6f           NaT           NaT
# 000095de-8e2b-82f1-32a7-c222ba3d5682           NaT           NaT
#
#                                       num_funding_rounds  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                 7.0
# 00002470-bff7-6226-5800-0ca1b3787b6f                 5.0
# 000095de-8e2b-82f1-32a7-c222ba3d5682                 1.0
#
#                                       duration_to_acquisition_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                            NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                            NaN
# 000095de-8e2b-82f1-32a7-c222ba3d5682                            NaN
#
#                                       duration_to_ipo_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                    NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                    NaN
# 000095de-8e2b-82f1-32a7-c222ba3d5682                    NaN
#
#                                       duration_to_closed_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                       NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                       NaN
# 000095de-8e2b-82f1-32a7-c222ba3d5682                       NaN
#
#                                       duration_to_current_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                        4.2
# 00002470-bff7-6226-5800-0ca1b3787b6f                        8.0
# 000095de-8e2b-82f1-32a7-c222ba3d5682                       20.0
#
#                                       duration_to_seed_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                     NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                    0.59
# 000095de-8e2b-82f1-32a7-c222ba3d5682                     NaN
#
#                                       duration_to_series_a_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                         NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                         NaN
# 000095de-8e2b-82f1-32a7-c222ba3d5682                         NaN
#
#                                       duration_to_series_b_years  \
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                         NaN
# 00002470-bff7-6226-5800-0ca1b3787b6f                         NaN
# 000095de-8e2b-82f1-32a7-c222ba3d5682                         NaN
#
#                                       duration_to_series_c_years  outcome
# org_uuid
# 000014da-0c46-b9cb-0941-3a93c027b119                         NaN        0
# 00002470-bff7-6226-5800-0ca1b3787b6f                         NaN        0
# 000095de-8e2b-82f1-32a7-c222ba3d5682                         NaN        0

# %%
#import main organisation csv
org_ori_df = pd.read_csv(R"d:/msc-project/data/pre-processed/organisations_preprocessed.csv",encoding='utf-8',
                         index_col='org_uuid',
                         parse_dates= ['founded_on','went_public_on','acquired_on','closed_on'])

# %%
org_ori_df.head(3)
# Out:
#                                           name          legal_name  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint                 NaN
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0      Digg  Digg Holdings, LLC
# df662812-7f97-0b43-9d3e-12f64f504fbb  Facebook      Facebook, Inc.
#
#                                                   homepage_url country_code  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd  http://www.wetpaint.com/          USA
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0       http://www.digg.com          USA
# df662812-7f97-0b43-9d3e-12f64f504fbb   http://www.facebook.com          USA
#
#                                      state_code      region        city  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd         NY    New York    New York
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0         NY    New York    New York
# df662812-7f97-0b43-9d3e-12f64f504fbb         CA  California  Menlo Park
#
#                                                           address postal_code  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd  902 Broadway 11th Floor New       10010
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                          NaN         NaN
# df662812-7f97-0b43-9d3e-12f64f504fbb                 1 Hacker Way       94025
#
#                                         status  ... acquirer_state_code  \
# org_uuid                                        ...
# e1393508-30ea-8a36-3f96-dd3226033abd  acquired  ...                  NY
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0  acquired  ...                  NY
# df662812-7f97-0b43-9d3e-12f64f504fbb       ipo  ...                 NaN
#
#                                      acquirer_region acquirer_city  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd        New York      New York
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0        New York      New York
# df662812-7f97-0b43-9d3e-12f64f504fbb             NaN           NaN
#
#                                       acquisition_type  acquired_on  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd       acquisition   2013-12-16
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0       acquisition   2012-07-12
# df662812-7f97-0b43-9d3e-12f64f504fbb               NaN          NaT
#
#                                        price_usd       price  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd  30000000.0  30000000.0
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0  16000000.0  16000000.0
# df662812-7f97-0b43-9d3e-12f64f504fbb         NaN         NaN
#
#                                      price_currency_code parent_uuid  \
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd                 USD         NaN
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                 USD         NaN
# df662812-7f97-0b43-9d3e-12f64f504fbb                 NaN         NaN
#
#                                      parent_name
# org_uuid
# e1393508-30ea-8a36-3f96-dd3226033abd         NaN
# 5f2b40b8-d1b3-d323-d81a-b7a8e89553d0         NaN
# df662812-7f97-0b43-9d3e-12f64f504fbb         NaN
#
# [3 rows x 57 columns]
